# %%
import sys 
sys.path.append('..')
import matplotlib.pyplot as plt 
import seaborn as sns  
import quarantines as Q 
import networkx as nx

# %%
N = 10 ** 4
G = nx.barabasi_albert_graph(N, 4)

gamma = 0.1
tau = 0.1 
rho = 0.0005

# %%
Q.plot_vanilla_run(G, gamma, tau, rho, float('inf'))

# %%
Q.quarantines_by_time(G, tau, gamma, rho, [0.01 * _ for _ in range(100)], float('inf')).plot_single()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
