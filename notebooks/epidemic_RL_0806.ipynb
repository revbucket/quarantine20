# %%
import sys 
sys.path.append('..')
import networkx as nx
import random
import quarantine_rl as qrl
import quarantines as Q
import matplotlib.pyplot as plt
import EoNlocal as EoN

# %%
G = nx.barabasi_albert_graph(10000, 3)

# %%
tau = 0.1
gamma = 0.1 
rho = 0.01

# %%
env = qrl.EnvironmentSIR(G, tau, gamma, rho)

# %%
env.reset()

# %%
env.dwise
# Out:
# tensor([[0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00],
#         [3.9850e+03, 3.8000e+01, 0.0000e+00],
#         [1.9520e+03, 1.2000e+01, 0.0000e+00],
#         [1.1400e+03, 1.2000e+01, 0.0000e+00],
#         [7.0500e+02, 1.5000e+01, 0.0000e+00],
#         [4.7500e+02, 4.0000e+00, 0.0000e+00],
#         [3.3400e+02, 7.0000e+00, 0.0000e+00],
#         [2.4400e+02, 2.0000e+00, 0.0000e+00],
#         [1.5000e+02, 1.0000e+00, 0.0000e+00],
#         [1.4000e+02, 1.0000e+00, 0.0000e+00],
#         [1.0600e+02, 1.0000e+00, 0.0000e+00],
#         [8.5000e+01, 0.0000e+00, 0.0000e+00],
#         [6.6000e+01, 1.0000e+00, 0.0000e+00],
#         [5.5000e+01, 1.0000e+00, 0.0000e+00],
#         [5.9000e+01, 0.0000e+00, 0.0000e+00],
#         [4.5000e+01, 1.0000e+00, 0.0000e+00],
#         [3.7000e+01, 0.0000e+00, 0.0000e+00],
#         [3.4000e+01, 1.0000e+00, 0.0000e+00],
# ...

# %%
env.dwise.sum(0)[2]
# Out:
# tensor(9208.)

# %%
total_reward = 0
for i in range(250):
    total_rewardenv.step(0)
    
env.step(1)
env.run_to_completion()

# %%
len(env.Q)

# %%
for i in range(1000):

# %%
len(env.reverse_status['I'])
