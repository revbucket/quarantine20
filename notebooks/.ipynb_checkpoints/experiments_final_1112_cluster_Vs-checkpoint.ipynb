# %%
import sys
sys.path.append('..')
import quarantines as Q
import quarantines_mongo as qm
import graph_generators as gg 
import networkx as nx 
import networkit as nk
import pymongo
import pickle
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

import seaborn as sns
from prettytable import PrettyTable
from tabulate import tabulate
from scipy import stats
from pprint import pprint
import os 
import random
import experiment_helpers as eh
import utils
import bisect
from curlyBrace import curlyBrace
sns.set()

# %%
# Gather and plot VGraphs for BA10 + FB 
data = eh.gather_data()
BA_KEY = 'ba_10_0.5'
FB_KEY = 'fb.artist'
SYNTH_KEYS = [_ for _ in data.keys() if _.endswith('_0.5') and not _.startswith('gemsec')]
REAL_KEYS = sorted([_ for _ in data.keys() if _.endswith('rHalf')])

# %%
REAL_KEYS
# Out:
# ['gemsec_fb_company_rHalf',
#  'gemsec_fb_athletes_rHalf',
#  'arxiv_GrQc_rHalf',
#  'arxiv_HepTh_rHalf',
#  'gemsec_fb_government_rHalf',
#  'arxiv_HepPh_rHalf',
#  'arxiv_CondMat_rHalf',
#  'gemsec_deezer_RO_rHalf',
#  'arxiv_AstroPh_rHalf',
#  'gemsec_fb_new_sites_rHalf',
#  'gemsec_deezer_HU_rHalf',
#  'gemsec_deezer_HR_rHalf',
#  'gemsec_fb_artist_rHalf']

# %%
pprint(sorted(data.keys()))
# Out:
# ['arxiv.AstroPh',
#  'arxiv.CondMat',
#  'arxiv.GrQc',
#  'arxiv.HepPh',
#  'arxiv.HepTh',
#  'arxiv_AstroPh_rHalf',
#  'arxiv_CondMat_rHalf',
#  'arxiv_GrQc_rHalf',
#  'arxiv_HepPh_rHalf',
#  'arxiv_HepTh_rHalf',
#  'ba10',
#  'ba10_bigiter',
#  'ba5',
#  'ba_10_0.03125',
#  'ba_10_0.0625',
#  'ba_10_0.125',
#  'ba_10_0.25',
#  'ba_10_0.5',
#  'ba_10_1',
#  'ba_10_2',
#  'ba_10_4',
#  'ba_10_8',
#  'ba_5_0.03125',
#  'ba_5_0.0625',
#  'ba_5_0.125',
#  'ba_5_0.25',
#  'ba_5_0.5',
#  'ba_5_1',
#  'ba_5_2',
#  'ba_5_4',
#  'ba_5_8',
#  'deezer.HR',
#  'deezer.HU',
#  'deezer.RO',
#  'fb.artist',
#  'fb.athletes',
#  'fb.company',
#  'fb.government',
#  'fb.new_sites',
#  'fbartist_bigiter',
#  'gemsec_deezer_HR_rHalf',
#  'gemsec_deezer_HU_rHalf',
#  'gemsec_deezer_RO_rHalf',
#  'gemsec_fb_ARTIST_R_0.03125',
#  'gemsec_fb_ARTIST_R_0.0625',
#  'gemsec_fb_ARTIST_R_0.125',
#  'gemsec_fb_ARTIST_R_0.25',
#  'gemsec_fb_ARTIST_R_0.5',
#  'gemsec_fb_ARTIST_R_1',
#  'gemsec_fb_ARTIST_R_16',
#  'gemsec_fb_ARTIST_R_2',
#  'gemsec_fb_ARTIST_R_32',
#  'gemsec_fb_ARTIST_R_4',
#  'gemsec_fb_ARTIST_R_8',
#  'gemsec_fb_artist_rHalf',
#  'gemsec_fb_athletes_rHalf',
#  'gemsec_fb_company_rHalf',
#  'gemsec_fb_government_rHalf',
#  'gemsec_fb_new_sites_rHalf',
#  'hiv50R1',
#  'hiv50R3',
#  'hiv50R5',
#  'hs15_10',
#  'hs30_10',
#  'hs5_10',
#  'hs60_10',
#  'nn.886',
#  'nn_0.88_6_0.03125',
#  'nn_0.88_6_0.0625',
#  'nn_0.88_6_0.125',
#  'nn_0.88_6_0.25',
#  'nn_0.88_6_0.5',
#  'nn_0.88_6_1',
#  'nn_0.88_6_2',
#  'nn_0.88_6_4',
#  'nn_0.88_6_8',
#  'plc10.25',
#  'plc5.5',
#  'plc_10_0.25_0.03125',
#  'plc_10_0.25_0.0625',
#  'plc_10_0.25_0.125',
#  'plc_10_0.25_0.25',
#  'plc_10_0.25_0.5',
#  'plc_10_0.25_1',
#  'plc_10_0.25_2',
#  'plc_10_0.25_4',
#  'plc_10_0.25_8',
#  'plc_5_0.5_0.03125',
#  'plc_5_0.5_0.0625',
#  'plc_5_0.5_0.125',
#  'plc_5_0.5_0.25',
#  'plc_5_0.5_0.5',
#  'plc_5_0.5_1',
#  'plc_5_0.5_2',
#  'plc_5_0.5_4',
#  'plc_5_0.5_8',
#  'rw.91.94',
#  'rw_0.91_0.94_0.03125',
#  'rw_0.91_0.94_0.0625',
#  'rw_0.91_0.94_0.125',
#  'rw_0.91_0.94_0.25',
#  'rw_0.91_0.94_0.5',
#  'rw_0.91_0.94_1',
#  'rw_0.91_0.94_2',
#  'rw_0.91_0.94_4',
#  'rw_0.91_0.94_8',
#  'ws10.05',
#  'ws_10_0.05_0.03125',
#  'ws_10_0.05_0.0625',
#  'ws_10_0.05_0.125',
#  'ws_10_0.05_0.25',
#  'ws_10_0.05_0.5',
#  'ws_10_0.05_1',
#  'ws_10_0.05_2',
#  'ws_10_0.05_4',
#  'ws_10_0.05_8']

# %%
SYNTH_KEYS
# Out:
# ['ws_10_0.05_0.5',
#  'ba_5_0.5',
#  'plc_5_0.5_0.5',
#  'ba_10_0.5',
#  'rw_0.91_0.94_0.5',
#  'plc_10_0.25_0.5',
#  'nn_0.88_6_0.5']

# %%
c = lambda i: list(mcolors.TABLEAU_COLORS)[i]
def name_mapper(k):
    short = k.split('_')[0]
    return {'ws': 'Watts Strogatz', 
            'ba': 'Barabasi-Albert', 
            'plc': 'Powerlaw Cluster', 
            'rw': 'Random Walk', 
            'nn': 'Nearest Neighbor'}[short]

# %%
def get_single_v(name, second_wave=0.05, no_filter=False):
    """ A little complicated: 
        - Collects data and partitions by qprop 
        - Then splits into "alive" and "dead" groups, depending on presence of "second wave"
          by determining if final#R is > (1+second_wave) * qprop
        - For qprops with no living groups, reports the pop average
    Ultimately returns a list of 
        [(qprop, livingMean, livingStd)] for all qprops
    """
    N = len(eh.parse_data_name(name))
    series = sorted(eh.group_by_qprop(data[name]).items())
    output = [] 
    for qprop, prop_list in series:
        Rs = [_ / N for _ in prop_list['final_R']] 
        live_Rs = [_ for _ in Rs if _ > (1 + second_wave) * qprop]
        if len(live_Rs) == 0 or no_filter:
            live_Rs = Rs
        output.append((qprop, np.mean(live_Rs), np.std(live_Rs)))
    return output 
    
    
    
def plot_single_v(name, fig, ax, c, label=None, second_wave=0.05, no_filter=False):
    triplist = get_single_v(name, second_wave=second_wave, no_filter=no_filter)
    ax.plot(*utils.select_mean(triplist), color=c, label=label)
    ax.fill_between(*utils.plotfill_trips(triplist), color=c, alpha=0.2)
    return min(triplist, key=lambda t: t[1])[0]


def plot_i_v(name, fig, ax, c, label=None, ls='solid'):
    N = len(eh.parse_data_name(name))
    series = sorted(eh.group_by_qprop(data[name]).items())
    triplist = [] 
    for qprop, prop_list in series:
        Is = [_ / N for _ in prop_list['max_I']] 
        triplist.append((qprop, np.mean(Is), np.std(Is)))
    ax.plot(*utils.select_mean(triplist), color=c, label=label, ls=ls)
    ax.fill_between(*utils.plotfill_trips(triplist), color=c, alpha=0.2)    
    return min(triplist, key=lambda t: t[1])[0]

# %%
def full_plot(name, fig, ax):
    xbreak2 = plot_single_v(name, fig, ax, 'b', label='Total I')
    xbreak1 = plot_i_v(name, fig, ax, 'r', label='Max I')
    print(xbreak1, xbreak2)
    ax.legend()
    brace_height = 0.25
    ax.plot([xbreak1, xbreak1], [brace_height, 1], c='k', alpha=0.2, ls='--')
    ax.plot([xbreak2, xbreak2], [brace_height, 1], c='k', alpha=0.2, ls='--')
    
    curlyBrace(fig, ax, (xbreak1, brace_height), (0.0, brace_height), c='c', str_text='Second Wave larger')
    curlyBrace(fig, ax, (xbreak2, brace_height), (xbreak1, brace_height), c='m', str_text='First Wave larger')
    curlyBrace(fig, ax, (1.0, brace_height), (xbreak2, brace_height), c='y', str_text='No Second Wave')
    
    
    ax.set_ylim(0, 1.0)
    ax.set_xlabel('Quarantine Threshold')
    ax.set_ylabel('Proportion of Population')

# %%
fig, ax = plt.subplots(figsize=(8,8))
full_plot(BA_KEY, fig, ax)
ax.set_title('Total/Max of Infected Nodes vs Quarantine Thresold')
# Out:
# 0.31 0.74
# Text(0.5, 1.0, 'Total/Max of Infected Nodes vs Quarantine Thresold')

# %%
fig, ax = plt.subplots(figsize=(8,8))
full_plot(FB_KEY, fig, ax)
ax.set_title('Total/Max of Infected Nodes vs Quarantine Thresold ')
# Out:
# 0.28 0.62
# Text(0.5, 1.0, 'Total/Max of Infected Nodes vs Quarantine Thresold ')

# %%
fig, ax = plt.subplots(figsize=(8,8))

for i, k in enumerate([_ for _ in SYNTH_KEYS if _ not in ['ba_5_0.5']]):
    plot_single_v(k, fig, ax, utils.c(i), label=name_mapper(k), no_filter=False)
    plot_i_v(k, fig, ax, utils.c(i), ls='--')

ax.legend()
ax.set_xlabel('Quarantine Threshold')
ax.set_ylabel('Proportion of Population')
ax.set_ylim(0, 1)
ax.set_title('Total/Max of Infected Nodes vs Quarantine Thresold')
# Out:
# Text(0.5, 1.0, 'Total/Max of Infected Nodes vs Quarantine Thresold')

# %%
pprint(sorted(REAL_KEYS))
# Out:
# ['arxiv_AstroPh_rHalf',
#  'arxiv_CondMat_rHalf',
#  'arxiv_GrQc_rHalf',
#  'arxiv_HepPh_rHalf',
#  'arxiv_HepTh_rHalf',
#  'gemsec_deezer_HR_rHalf',
#  'gemsec_deezer_HU_rHalf',
#  'gemsec_deezer_RO_rHalf',
#  'gemsec_fb_artist_rHalf',
#  'gemsec_fb_athletes_rHalf',
#  'gemsec_fb_company_rHalf',
#  'gemsec_fb_government_rHalf',
#  'gemsec_fb_new_sites_rHalf']

# %%
'gemsec_fb_government_rHalf'[10:-6]
# Out:
# 'government'

# %%
REAL_KEYS
# Out:
# ['gemsec_fb_company_rHalf',
#  'gemsec_fb_athletes_rHalf',
#  'arxiv_GrQc_rHalf',
#  'arxiv_HepTh_rHalf',
#  'gemsec_fb_government_rHalf',
#  'arxiv_HepPh_rHalf',
#  'arxiv_CondMat_rHalf',
#  'gemsec_deezer_RO_rHalf',
#  'arxiv_AstroPh_rHalf',
#  'gemsec_fb_new_sites_rHalf',
#  'gemsec_deezer_HU_rHalf',
#  'gemsec_deezer_HR_rHalf',
#  'gemsec_fb_artist_rHalf']

# %%
fig, ax = plt.subplots(figsize=(8,8))
def name_mapper(k):
    if k.startswith('gemsec_fb'):
        val = k[10:-6]
        return 'fb.' +val
    elif k.startswith('gemsec_deezer'):
        return 'deezer.' +k.split('_')[2]
    else:
        return 'arxiv.' + k.split('_')[1]
        
        
for i, k in enumerate([_ for _ in REAL_KEYS if _.startswith('gemsec')]):# if _.startswith('fb') or _.startswith('deezer')]):
    plot_single_v(k, fig, ax, c(i), label=name_mapper(k), no_filter=False)
    #plot_i_v(k, fig, ax, c(i), ls='--')

ax.legend()
ax.set_xlabel('Quarantine Threshold')
ax.set_ylabel('Proportion of Population')
ax.set_ylim(0, 1)
ax.set_title('Total/Max of Infected Nodes vs Quarantine Thresold')
# Out:
# Text(0.5, 1.0, 'Total/Max of Infected Nodes vs Quarantine Thresold')

# %%
fig, ax = plt.subplots(figsize=(8,8))

for i, k in enumerate([_ for _ in REAL_KEYS if _.startswith('arxiv')]):
    plot_single_v(k, fig, ax, c(i), label=(name_mapper(k)), no_filter=False)
    #plot_i_v(k, fig, ax, c(i), ls='--')

ax.legend()
ax.set_xlabel('Quarantine Threshold')
ax.set_ylabel('Proportion of Population')
ax.set_ylim(0, 1)
ax.set_title('Total/Max of Infected Nodes vs Quarantine Thresold')
# Out:
# Text(0.5, 1.0, 'Total/Max of Infected Nodes vs Quarantine Thresold')
