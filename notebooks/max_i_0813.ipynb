# %%
import sys 
sys.path.append('..')

import EoNlocal as EoN
import quarantines as Q
import quarantines_mongo as qm

import networkx as nx 
import numpy as np 
import random

# %%
N = 10000
G = nx.barabasi_albert_graph(N, 3)

tau = 0.1 
gamma = 0.1 
rho = 10 / N

# %%
Q.plot_vanilla_run(G, tau, gamma, rho, float('inf'))

# %%
output = Q.quarantine_by_prop(G, tau, gamma, rho, [20/ N for _ in range(N / 20)], float('inf'), term_I=True, num_iter=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-bc054527c917> in <module>
# ----> 1 output = Q.quarantine_by_prop(G, tau, gamma, rho, [20/ N for _ in range(N / 20)], float('inf'), term_I=True, num_iter=2)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
[_.count for _ in output.tup_list]
# Out:
# [101, 101]

# %%
output.plot_single()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
