# %%
import sys 
sys.path.append('..')
import networkx as nx
import EoNlocal as EoN
import quarantines as Q
import matplotlib.pyplot as plt

# %%
edges = [] 
with open('../snap/facebook/facebook_combined.txt', 'r') as f: 
    for line in f.readlines():
        edges.append([int(_) for _ in line.strip().split()])

# %%
G = nx.read_adjlist('../snap/facebook/facebook_combined.txt', 'r')

# %%
N = len(G)
Q.plot_vanilla_run(G, 0.1, 0.1, 10 / N, float('inf') )

# %%
Q.quarantine_by_prop(G, 0.1, 0.1, 10 / N, [0.6], float('inf'), num_iter=5).plot_single()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
G = nx.read_adjlist('../snap/gemsec_fb/facebook_clean_data/new_politician_edges.csv')

# %%
# Out:
# 41730
