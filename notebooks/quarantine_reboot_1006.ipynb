# %%
# IMPORT BLOCK
import sys 
sys.path.append('..')
import networkx as nx 
import matplotlib.pyplot as plt 
import numpy as np
import EoNlocal as EoN
import time
import seaborn as sns
import quarantines as Q

# %%
N = 10 ** 4

tau = 0.1
gamma = 0.1 
rho = 10 / N

# %%
Q.plot_vanilla_run(G, tau, gamma, rho, float('inf'))

# %%
Q.quarantine_by_prop(G, tau, gamma, rho, [0.54], float('inf'), num_iter=10).plot_single()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
low_deg_G = G.copy()
ld_dict = dict(low_deg_G.degree)
high_deg_nodes = [_[0] for _ in sorted(ld_dict.items(), key=lambda i: -i[1])[:int(N * 0.10)]]
low_deg_G.remove_nodes_from(high_deg_nodes)
print(len(low_deg_G))
Q.plot_vanilla_run(low_deg_G, tau, gamma, 1 / N, float('inf'))
# Out:
# 9000
# ...
