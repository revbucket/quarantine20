# %%
import sys
sys.path.append('..')
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import EoNlocal as EoN
import time
import seaborn as sns
import utils

import quarantines as Q

# %%
# SIMPLE SETUP 
N = 10 ** 4
G = nx.barabasi_albert_graph(N, 8)

tmax = float('inf')
iterations = 5  #run 5 simulations
tau = 0.15        #transmission rate
gamma = 1.0    #recovery rate
rho = 0.005      #random fraction initially infected

# %%
G2, tup_out = Q.run_until_time(G, tau, gamma ,rho, tmax=2.0)

# %%
Q.degree_transition_dict(G, G2)
# Out:
# {203: {'original': 1, 'final': 0},
#  307: {'original': 1, 'final': 0},
#  174: {'original': 1, 'final': 0},
#  226: {'original': 1, 'final': 0},
#  194: {'original': 1, 'final': 0},
#  140: {'original': 1, 'final': 0},
#  99: {'original': 3, 'final': 0},
#  228: {'original': 1, 'final': 0},
#  450: {'original': 1, 'final': 0},
#  382: {'original': 1, 'final': 0},
#  420: {'original': 1, 'final': 0},
#  523: {'original': 1, 'final': 0},
#  306: {'original': 1, 'final': 0},
#  302: {'original': 1, 'final': 0},
#  288: {'original': 1, 'final': 0},
#  250: {'original': 1, 'final': 0},
#  273: {'original': 1, 'final': 0},
#  245: {'original': 1, 'final': 0},
#  222: {'original': 1, 'final': 0},
#  354: {'original': 1, 'final': 0},
#  304: {'original': 1, 'final': 0},
#  257: {'original': 1, 'final': 0},
#  227: {'original': 1, 'final': 0},
#  232: {'original': 1, 'final': 0},
#  205: {'original': 1, 'final': 0},
#  204: {'original': 1, 'final': 0},
#  343: {'original': 1, 'final': 0},
#  234: {'original': 1, 'final': 0},
#  145: {'original': 1, 'final': 0},
#  192: {'original': 1, 'final': 0},
#  128: {'original': 1, 'final': 0},
#  114: {'original': 1, 'final': 0},
#  210: {'original': 1, 'final': 0},
#  143: {'original': 1, 'final': 0},
#  199: {'original': 1, 'final': 0},
#  131: {'original': 1, 'final': 0},
#  74: {'original': 3, 'final': 0},
#  93: {'original': 2, 'final': 0},
#  147: {'original': 1, 'final': 0},
#  198: {'original': 1, 'final': 0},
#  137: {'original': 1, 'final': 0},
#  89: {'original': 2, 'final': 0},
#  130: {'original': 2, 'final': 0},
#  161: {'original': 1, 'final': 0},
#  132: {'original': 2, 'final': 0},
#  165: {'original': 1, 'final': 0},
#  109: {'original': 1, 'final': 0},
#  121: {'original': 1, 'final': 0},
#  220: {'original': 1, 'final': 0},
#  117: {'original': 2, 'final': 0},
#  106: {'original': 1, 'final': 0},
#  53: {'original': 9, 'final': 1, 28: 1},
#  87: {'original': 5, 'final': 1, 41: 1},
#  144: {'original': 2, 'final': 0},
#  81: {'original': 1, 'final': 0},
#  136: {'original': 2, 'final': 0},
#  76: {'original': 7, 'final': 0},
#  96: {'original': 2, 'final': 0},
#  105: {'original': 2, 'final': 0},
#  124: {'original': 1, 'final': 0},
#  58: {'original': 7, 'final': 1, 28: 1},
#  51: {'original': 11, 'final': 1, 26: 1},
#  80: {'original': 4, 'final': 0},
#  103: {'original': 3, 'final': 0},
#  63: {'original': 8, 'final': 0},
#  91: {'original': 2, 'final': 0},
#  141: {'original': 2, 'final': 0},
#  23: {'original': 104,
#   'final': 44,
#   6: 2,
#   11: 8,
#   7: 1,
#   12: 5,
#   14: 2,
#   10: 9,
#   9: 4,
#   13: 6,
#   15: 4,
#   16: 2,
#   17: 1},
#  154: {'original': 1, 'final': 0},
#  85: {'original': 2, 'final': 1, 36: 1},
#  108: {'original': 1, 'final': 0},
#  86: {'original': 2, 'final': 0},
#  54: {'original': 8, 'final': 0},
#  52: {'original': 11, 'final': 4, 24: 1, 26: 2, 32: 1},
#  40: {'original': 14, 'final': 5, 16: 1, 17: 1, 21: 1, 22: 2},
#  79: {'original': 3, 'final': 0},
#  49: {'original': 7, 'final': 0},
#  84: {'original': 3, 'final': 0},
#  60: {'original': 7, 'final': 2, 25: 2},
#  71: {'original': 5, 'final': 0},
#  97: {'original': 2, 'final': 0},
#  173: {'original': 1, 'final': 0},
#  112: {'original': 1, 'final': 0},
#  56: {'original': 10, 'final': 4, 34: 1, 32: 1, 30: 1, 25: 1},
#  151: {'original': 1, 'final': 0},
#  107: {'original': 2, 'final': 0},
#  110: {'original': 1, 'final': 0},
#  78: {'original': 5, 'final': 0},
#  28: {'original': 63,
#   'final': 17,
#   11: 4,
#   13: 5,
#   12: 1,
#   14: 3,
#   16: 1,
#   18: 1,
#   17: 1,
#   19: 1},
#  37: {'original': 33, 'final': 5, 15: 2, 19: 1, 18: 1, 21: 1},
#  75: {'original': 3, 'final': 0},
#  83: {'original': 3, 'final': 0},
#  77: {'original': 1, 'final': 0},
#  72: {'original': 2, 'final': 0},
#  68: {'original': 2, 'final': 0},
#  25: {'original': 90,
#   'final': 37,
#   10: 5,
#   14: 6,
#   13: 8,
#   11: 4,
#   12: 2,
#   15: 6,
#   7: 1,
#   9: 1,
#   17: 2,
#   18: 2},
#  98: {'original': 1, 'final': 0},
#  67: {'original': 2, 'final': 0},
#  82: {'original': 3, 'final': 1, 45: 1},
#  38: {'original': 39,
#   'final': 15,
#   21: 3,
#   15: 3,
#   17: 2,
#   18: 2,
#   19: 2,
#   20: 1,
#   25: 1,
#   27: 1},
#  66: {'original': 6, 'final': 0},
#  55: {'original': 9, 'final': 2, 30: 1, 24: 1},
#  70: {'original': 2, 'final': 0},
#  31: {'original': 42, 'final': 7, 15: 2, 11: 1, 16: 2, 14: 1, 19: 1},
#  90: {'original': 1, 'final': 0},
#  61: {'original': 8, 'final': 1, 39: 1},
#  45: {'original': 18, 'final': 2, 25: 2},
#  32: {'original': 39,
#   'final': 14,
#   13: 1,
#   15: 1,
#   14: 5,
#   19: 1,
#   12: 1,
#   10: 1,
#   20: 1,
#   16: 1,
#   23: 1,
#   22: 1},
#  59: {'original': 6, 'final': 0},
#  26: {'original': 74,
#   'final': 28,
#   10: 4,
#   11: 5,
#   14: 2,
#   9: 1,
#   16: 3,
#   12: 3,
#   15: 1,
#   13: 4,
#   17: 4,
#   18: 1},
#  57: {'original': 3, 'final': 0},
#  95: {'original': 1, 'final': 0},
#  42: {'original': 17, 'final': 3, 25: 1, 21: 1, 26: 1},
#  104: {'original': 2, 'final': 0},
#  64: {'original': 6, 'final': 0},
#  62: {'original': 6, 'final': 0},
#  44: {'original': 19, 'final': 5, 24: 2, 23: 2, 18: 1},
#  50: {'original': 10, 'final': 3, 28: 1, 24: 1, 23: 1},
#  65: {'original': 11, 'final': 1, 31: 1},
#  47: {'original': 11, 'final': 2, 26: 1, 24: 1},
#  39: {'original': 24,
#   'final': 8,
#   16: 1,
#   18: 1,
#   15: 1,
#   17: 1,
#   23: 1,
#   22: 2,
#   20: 1},
#  73: {'original': 1, 'final': 0},
#  34: {'original': 33,
#   'final': 9,
#   14: 3,
#   16: 1,
#   19: 1,
#   22: 1,
#   18: 1,
#   20: 1,
#   23: 1},
#  113: {'original': 1, 'final': 1, 63: 1},
#  94: {'original': 1, 'final': 0},
#  35: {'original': 30,
#   'final': 9,
#   16: 1,
#   17: 1,
#   19: 2,
#   15: 1,
#   22: 1,
#   20: 2,
#   14: 1},
#  41: {'original': 20, 'final': 4, 19: 2, 21: 1, 25: 1},
#  69: {'original': 3, 'final': 0},
#  43: {'original': 14, 'final': 1, 19: 1},
#  46: {'original': 13, 'final': 2, 21: 1, 22: 1},
#  36: {'original': 22,
#   'final': 8,
#   16: 2,
#   11: 1,
#   19: 1,
#   17: 1,
#   20: 1,
#   22: 1,
#   26: 1},
#  30: {'original': 61,
#   'final': 20,
#   13: 2,
#   16: 2,
#   17: 2,
#   14: 4,
#   15: 5,
#   12: 2,
#   18: 2,
#   19: 1},
#  24: {'original': 106,
#   'final': 54,
#   8: 5,
#   7: 2,
#   15: 4,
#   11: 9,
#   9: 7,
#   10: 6,
#   12: 7,
#   16: 3,
#   13: 2,
#   14: 9},
#  33: {'original': 30, 'final': 11, 12: 2, 17: 3, 14: 2, 15: 1, 16: 2, 19: 1},
#  48: {'original': 13, 'final': 2, 26: 1, 24: 1},
#  29: {'original': 50,
#   'final': 19,
#   9: 1,
#   14: 6,
#   16: 6,
#   15: 2,
#   10: 1,
#   18: 2,
#   17: 1},
#  92: {'original': 1, 'final': 0},
#  27: {'original': 54,
#   'final': 23,
#   12: 1,
#   8: 1,
#   7: 1,
#   15: 4,
#   13: 2,
#   11: 2,
#   14: 5,
#   18: 1,
#   19: 1,
#   16: 3,
#   10: 1,
#   17: 1},
#  16: {'original': 281,
#   'final': 154,
#   4: 4,
#   5: 14,
#   10: 20,
#   7: 27,
#   8: 30,
#   6: 15,
#   9: 33,
#   11: 8,
#   3: 1,
#   12: 2},
#  20: {'original': 172,
#   'final': 87,
#   8: 12,
#   12: 6,
#   9: 15,
#   10: 14,
#   11: 16,
#   6: 4,
#   7: 7,
#   13: 7,
#   15: 3,
#   14: 2,
#   4: 1},
#  19: {'original': 154,
#   'final': 78,
#   9: 14,
#   10: 12,
#   7: 7,
#   4: 1,
#   12: 8,
#   8: 13,
#   6: 3,
#   11: 15,
#   5: 1,
#   13: 3,
#   14: 1},
#  22: {'original': 114,
#   'final': 55,
#   11: 9,
#   8: 5,
#   10: 9,
#   12: 9,
#   9: 8,
#   13: 6,
#   14: 6,
#   15: 2,
#   16: 1},
#  14: {'original': 431,
#   'final': 254,
#   5: 37,
#   3: 7,
#   7: 60,
#   8: 49,
#   6: 42,
#   4: 16,
#   2: 1,
#   9: 21,
#   10: 14,
#   11: 4,
#   1: 1,
#   12: 2},
#  21: {'original': 146,
#   'final': 67,
#   10: 8,
#   8: 7,
#   9: 13,
#   13: 4,
#   6: 1,
#   7: 5,
#   12: 13,
#   11: 9,
#   16: 1,
#   14: 4,
#   5: 1,
#   15: 1},
#  18: {'original': 207,
#   'final': 87,
#   8: 13,
#   6: 10,
#   4: 1,
#   10: 14,
#   7: 12,
#   11: 8,
#   9: 19,
#   12: 9,
#   15: 1},
#  17: {'original': 241,
#   'final': 135,
#   7: 28,
#   6: 13,
#   4: 2,
#   9: 27,
#   10: 17,
#   8: 24,
#   11: 15,
#   5: 7,
#   13: 2},
#  15: {'original': 365,
#   'final': 212,
#   6: 25,
#   7: 52,
#   8: 36,
#   5: 23,
#   9: 30,
#   3: 1,
#   4: 10,
#   10: 24,
#   2: 1,
#   11: 7,
#   12: 3},
#  13: {'original': 509,
#   'final': 299,
#   3: 21,
#   4: 27,
#   6: 63,
#   5: 58,
#   2: 4,
#   7: 61,
#   8: 36,
#   9: 20,
#   10: 6,
#   11: 3},
#  9: {'original': 1393,
#   'final': 931,
#   4: 230,
#   2: 83,
#   3: 189,
#   1: 24,
#   0: 10,
#   5: 221,
#   7: 49,
#   6: 119,
#   8: 5,
#   9: 1},
#  11: {'original': 854,
#   'final': 561,
#   3: 47,
#   4: 98,
#   7: 83,
#   5: 142,
#   6: 132,
#   2: 18,
#   8: 32,
#   1: 2,
#   9: 6,
#   10: 1},
#  12: {'original': 665,
#   'final': 405,
#   2: 6,
#   5: 83,
#   3: 31,
#   7: 65,
#   4: 57,
#   6: 98,
#   8: 45,
#   10: 4,
#   9: 14,
#   11: 2},
#  10: {'original': 1139,
#   'final': 766,
#   7: 71,
#   1: 10,
#   6: 141,
#   3: 124,
#   4: 161,
#   5: 185,
#   2: 41,
#   0: 1,
#   8: 26,
#   9: 6},
#  8: {'original': 2000,
#   'final': 1428,
#   3: 363,
#   1: 84,
#   2: 242,
#   4: 360,
#   5: 254,
#   0: 12,
#   6: 84,
#   7: 25,
#   8: 4}}

# %%
invert_start = utils.invert_dict(dict(G.degree)) # degree -> list of nodes 
end_degree = dict(G2.degree )
output_dict = {} 
start_deg = 34
node_list = invert_start[start_deg]
#print(start_deg, node_list)
{node: end_degree[node] for node in node_list if node in end_degree}

# %%
G.degree[331], G2.degree[331]

# %%
331 in dict(end_degree)

# %%
invert_start.keys()

# %%
end_degree

# %%
# This graph has a basic SIR run that looks like this (plotting)
Q.plot_vanilla_run(G, tau, gamma, rho, tmax, series='IRZ')

# %%
# quick maffs to check how much memory I can store 
import time 
s = time.time()
tup = Q.quarantines_by_time(G, tau, gamma, rho, [2.0], tmax, num_iter=1)
print("RUNTIME", time.time() - s)
# How many runs can I handle with 2GB ram (I can always save stats only...)
GB = 2
GB_in_kb = GB * 10 **6
num_objects = GB_in_kb / (sys.getsizeof(tup.t) / 1000 * 4)
num_trials = 10
print("GRIDSIZE", (num_objects / num_trials) ** 0.5)

# %%
# Get fairly fine-grained 'by-proportion' quarantine heatmap (we can always filter this down)

# %%
proprange = [_ / 100 for _ in range(0, 21)]
small_proprange = [_ / 20 for _ in range(0, 14)]

# %%
small_proprange

# %%
data_grid = Q.get_quarantine_grid_data_props(G, tau, gamma, rho, tmax, small_proprange, small_proprange)

# %%
data_grid.

# %%
Q.heatmapify(*Q.process_into_grid(data_grid, Q.AggregateTuple.get_final_R), axlabels='prop')

# %%
# Make heatmaps based on changing the avg degree
grids_by_avg_deg = {}
for avg_deg in [5, 10, 15]:
    print("--------------------------------Working on deg %s -------------------------" % avg_deg)
    G_deg = nx.barabasi_albert_graph(N, avg_deg)
    deg_grid = Q.get_quarantine_grid_data_props(G_deg, tau, gamma, rho, tmax, small_proprange, small_proprange)
    grids_by_avg_deg[avg_deg] = deg_grid

# %%
Q.heatmapify(*Q.process_into_grid(grids_by_avg_deg[5], Q.AggregateTuple.get_final_R), axlabels='prop')

# %%
Q.heatmapify(*Q.process_into_grid(grids_by_avg_deg[10], Q.AggregateTuple.get_final_R), axlabels='prop')

# %%
Q.heatmapify(*Q.process_into_grid(grids_by_avg_deg[15], Q.AggregateTuple.get_final_R), axlabels='prop')

# %%
Q.heatmapify(*Q.process_into_grid(grids_by_avg_deg[15], Q.AggregateTuple.get_final_R), axlabels='prop')

# %%
G2 = nx.barabasi_albert_graph(N, 15)
Q.plot_vanilla_run(G2, tau, gamma, rho, tmax, series='IR')

# %%
prange_1 = [0.02 * _ for _ in range(1, 6)]

# %%
propdict = Q.get_quarantine_grid_data_props(G, tau, gamma, rho, float('inf'), prange_1, prange_1)

# %%
Q.heatmapify(*Q.process_into_grid(propdict, Q.AggregateTuple.get_final_R))

# %%
G2, propsum = Q.run_until_prop_IR(G, tau, gamma, rho, float('inf'), 0.1)

# %%
aggsum = Q.quarantine_by_prop(G, tau, gamma, rho, [0.1, 0.1, 0.1], float('inf'), num_iter=3)

# %%
aggsum.plot_single()

# %%
sys.path
